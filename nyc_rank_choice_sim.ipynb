# %%
"""
---- G O A L ----
1)  SIMULATE THE MOST ACURATE BALLOT DISTRIBUTION
2)  FIND POSSIBLE PATHS TO VICTORY FOR 2ND AND 3RD SEED CANDIDATES
3)  FIGURE OUT WHICH SIMULATION VARIABLES PRODUCED THE MOST ACCURATE BALLOTS 
---- P L A N ----
1)  create candidates
2)  create data structure for each candidate
        - contains dictionary: likely hood to rank each other candidate
---- SIM BEGINS ----
LOOP 
{
3)  create ballots from initial ranked choice voting
        - add to ballot -> if likely hood of selected a candidate is above X% add candidate to ballot
4)  run instant runoff and log winner
}
---- SIM STATS ----
5) Add and change parameters to simulate real life differences in ballots (threshold for additional ranking, confidence ranges of probabilites)
---- SOURCE DATA ----
6)  Find better way to get likely hood percentages (look at heat maps of leads)
7)  Consider implementing ranked choice voting strategies
---- RETRO ANALYSIS ----
8) COMPARE WHICH SIMULATIONS HAD THE CLOSEST BALLOTS TO ACTUAL DATA - LEARN WHICH FACTORS OF THE SIMULATION WERE MOST IMPORTANT


JUNE 23/24 -   MAKE DATA STRUCTURE AND SIM LOOP AND AGREGATE STATS AND GRAPHS
JUNE 23/24 -   ADD PARAMETERS THAT MAKE SIM MORE REALISTIC 
JUNE 28 -   SET UP RETROACTIVE RESEARCH EXCEPT FOR FINAL BALLOT DATA
                - CREATE COST FUNCTION BETWEEN MY BALLOTS AND TRUE BALLOTS
JUNE 29 -   DO RETROACTIVE RESEARCH - IMPORT AND FORMAT ACTUAL BALLOT DATA AND RUN
"""

# %%
import pyrankvote
from pyrankvote import Candidate, Ballot
import random
MAX_RANKS = 5
MIN_FAVOR = .5
ROUNDS = 30

adams = Candidate("adams")          #   0
wiley = Candidate("wiley")          #   1
garcia = Candidate("garcia")        #   2
yang = Candidate("yang")            #   3
stringer = Candidate("stringer")    #   4
morales = Candidate("morales")      #   5

candidates = [adams, wiley, garcia, yang, stringer, morales]
can_str = {"adams":adams,"wiley":wiley,"garcia":garcia,"yang":yang,"stringer":stringer,"morales":morales}
winners = {"adams": 0,"wiley":0,"garcia":0,"yang":0,"stringer":0,"morales":0}

first_votes = {}
first_votes["adams"] = 253234
first_votes["wiley"] = 177722
first_votes["garcia"] = 155812
first_votes["yang"] = 93291
first_votes["stringer"] = 40244
first_votes["morales"] = 22221

votes = 0
for values in first_votes.values():
    votes += values

for x in range(0,ROUNDS):
    favor_web = {}
    for can_a in candidates:
        favor_web[can_a.name] = {}
        for can_b in candidates:
            favor_web[can_a.name][can_b.name] = round(random.random(),2)
            if can_a.name == can_b.name:
                favor_web[can_a.name][can_b.name] = 1
                
    num_candidates = len(candidates)

    print(favor_web)

    # ADD ALL FAVOR WEB PROBABILITIES HERE

    ## yang and garcia campained together
    favor_web["yang"]["garcia"] = round(random.uniform(.5,.99),2)
    favor_web["garcia"]["yang"] = round(random.uniform(.5,.99),2)




    #BUILD BALLOTS with first choice filled
    ballots = [] 
    # ballot[x] = x individual ballots --> list of tuples 
    # ballot[x][y] = y tuples of candidate plus favorability
    # ballot[x][y][z] = z:0 is candidate obj and z:1 is favorability
    for i in range(0,votes):
        if(i>=0 and i<253234 ):
            ballots.append([(adams,1)])
        elif(i>=253234 and i<430956):
            ballots.append([(wiley,1)])
        elif(i>=430956 and i<586768):
            ballots.append([(garcia,1)])
        elif(i>=586768 and i<680059):
            ballots.append([(yang,1)])
        elif(i>=680059 and i<720303):
            ballots.append([(stringer,1)])
        else:
            ballots.append([(morales,1)])


    for ballot in ballots:
        name = ballot[0][0].name
        for other_peep in candidates:
            if name!=other_peep.name:
                if(favor_web[name][other_peep.name]>=MIN_FAVOR):
                    ballot.append((other_peep,favor_web[name][other_peep.name]))

    #FORMAT BALLOTS
    #sort by favorite
    for ballot in ballots:
        ballot.sort(key=lambda tup: tup[1], reverse=True)
        ballot = ballot[:MAX_RANKS]
    #create final data block
    ballots_formatted = []
    for ballot in ballots:
        ballots_formatted.append([a_tuple[0] for a_tuple in ballot])
    final_ballots = []
    for ballot in ballots_formatted:
        final_ballots.append(Ballot(ranked_candidates=ballot))  



    # You can use your own Candidate and Ballot objects as long as they implement the same properties and methods
    election_result = pyrankvote.instant_runoff_voting(candidates, final_ballots)

    winner = election_result.get_winners()[0]
    # Returns: [<Candidate('Al Gore (Democratic)')>]

    print(election_result)  
    winners[winner.name] += 1
# Out:
# , 'morales': 0.92}, 'wiley': {'adams': 0.4, 'wiley': 1, 'garcia': 0.23, 'yang': 0.23, 'stringer': 0.05, 'morales': 0.38}, 'garcia': {'adams': 0.35, 'wiley': 0.26, 'garcia': 1, 'yang': 0.91, 'stringer': 0.96, 'morales': 0.14}, 'yang': {'adams': 0.9, 'wiley': 0.97, 'garcia': 0.48, 'yang': 1, 'stringer': 0.38, 'morales': 0.03}, 'stringer': {'adams': 0.4, 'wiley': 0.65, 'garcia': 0.67, 'yang': 0.14, 'stringer': 1, 'morales': 0.15}, 'morales': {'adams': 0.66, 'wiley': 0.92, 'garcia': 0.38, 'yang': 0.42, 'stringer': 0.52, 'morales': 1}}
# ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# adams         253234  Hopeful
# wiley         177722  Hopeful
# garcia        155812  Hopeful
# yang           93291  Rejected
# stringer       40244  Rejected
# morales        22221  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# wiley         293234  Hopeful
# adams         253234  Hopeful
# garcia        196056  Rejected
# yang               0  Rejected
# stringer           0  Rejected
# morales            0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# adams         409046  Elected
# wiley         333478  Rejected
# garcia             0  Rejected
# yang               0  Rejected
# stringer           0  Rejected
# morales            0  Rejected
#
# {'adams': {'adams': 1, 'wiley': 0.58, 'garcia': 0.32, 'yang': 0.97, 'stringer': 0.41, 'morales': 0.8}, 'wiley': {'adams': 0.7, 'wiley': 1, 'garcia': 0.43, 'yang': 0.21, 'stringer': 0.24, 'morales': 0.24}, 'garcia': {'adams': 0.08, 'wiley': 0.26, 'garcia': 1, 'yang': 0.24, 'stringer': 0.29, 'morales': 0.43}, 'yang': {'adams': 0.64, 'wiley': 0.06, 'garcia': 0.63, 'yang': 1, 'stringer': 0.97, 'morales': 0.83}, 'stringer': {'adams': 0.6, 'wiley': 0.49, 'garcia': 0.6, 'yang': 0.77, 'stringer': 1, 'morales': 0.22}, 'morales': {'adams': 0.33, 'wiley': 0.75, 'garcia': 0.62, 'yang': 0.4, 'stringer': 0.25, 'morales': 1}}
# ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# adams         253234  Hopeful
# wiley         177722  Hopeful
# garcia        155812  Hopeful
# yang           93291  Rejected
# stringer       40244  Rejected
# morales        22221  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# adams         386769  Elected
# wiley         199943  Rejected
# garcia        155812  Rejected
# yang               0  Rejected
# stringer           0  Rejected
# morales            0  Rejected
#
# {'adams': {'adams': 1, 'wiley': 0.06, 'garcia': 0.25, 'yang': 0.53, 'stringer': 0.13, 'morales': 0.85}, 'wiley': {'adams': 0.02, 'wiley': 1, 'garcia': 0.09, 'yang': 0.94, 'stringer': 0.88, 'morales': 0.05}, 'garcia': {'adams': 0.68, 'wiley': 0.13, 'garcia': 1, 'yang': 0.11, 'stringer': 0.83, 'morales': 0.99}, 'yang': {'adams': 0.27, 'wiley': 0.63, 'garcia': 0.83, 'yang': 1, 'stringer': 0.35, 'morales': 0.55}, 'stringer': {'adams': 0.65, 'wiley': 0.01, 'garcia': 0.33, 'yang': 0.5, 'stringer': 1, 'morales': 0.29}, 'morales': {'adams': 0.95, 'wiley': 0.74, 'garcia': 0.96, 'yang': 0.75, 'stringer': 0.17, 'morales': 1}}
# ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# adams         253234  Hopeful
# wiley         177722  Hopeful
# garcia        155812  Hopeful
# yang           93291  Rejected
# stringer       40244  Rejected
# morales        22221  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# adams         293478  Hopeful
# garcia        271324  Hopeful
# wiley         177722  Rejected
# yang               0  Rejected
# stringer           0  Rejected
# morales            0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# adams         293478  Elected
# garcia        271324  Rejected
# wiley              0  Rejected
# yang               0  Rejected
# stringer           0  Rejected
# morales            0  Rejected
# Blank votes   177722  Rejected
#
# {'adams': {'adams': 1, 'wiley': 0.09, 'garcia': 0.87, 'yang': 0.42, 'stringer': 0.03, 'morales': 0.16}, 'wiley': {'adams': 0.26, 'wiley': 1, 'garcia': 0.96, 'yang': 0.36, 'stringer': 0.28, 'morales': 0.6}, 'garcia': {'adams': 0.18, 'wiley': 0.05, 'garcia': 1, 'yang': 0.21, 'stringer': 0.82, 'morales': 0.61}, 'yang': {'adams': 0.27, 'wiley': 0.8, 'garcia': 0.74, 'yang': 1, 'stringer': 0.46, 'morales': 0.87}, 'stringer': {'adams': 0.8, 'wiley': 0.59, 'garcia': 0.64, 'yang': 0.92, 'stringer': 1, 'morales': 0.61}, 'morales': {'adams': 0.65, 'wiley': 0.5, 'garcia': 0.39, 'yang': 0.19, 'stringer': 0.81, 'morales': 1}}
# ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# adams         253234  Hopeful
# wiley         177722  Hopeful
# garcia        155812  Hopeful
# yang           93291  Rejected
# stringer       40244  Rejected
# morales        22221  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# adams         315699  Hopeful
# wiley         271013  Hopeful
# garcia        155812  Rejected
# yang               0  Rejected
# stringer           0  Rejected
# morales            0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# adams         471511  Elected
# wiley         271013  Rejected
# garcia             0  Rejected
# yang               0  Rejected
# stringer           0  Rejected
# morales            0  Rejected
#
# {'adams': {'adams': 1, 'wiley': 0.82, 'garcia': 0.33, 'yang': 0.96, 'stringer': 0.43, 'morales': 0.48}, 'wiley': {'adams': 0.88, 'wiley': 1, 'garcia': 0.46, 'yang': 0.81, 'stringer': 0.17, 'morales': 0.06}, 'garcia': {'adams': 0.37, 'wiley': 0.07, 'garcia': 1, 'yang': 0.36, 'stringer': 0.96, 'morales': 0.86}, 'yang': {'adams': 0.17, 'wiley': 0.54, 'garcia': 0.74, 'yang': 1, 'stringer': 0.42, 'morales': 0.03}, 'stringer': {'adams': 0.3, 'wiley': 0.65, 'garcia': 0.63, 'yang': 0.35, 'stringer': 1, 'morales': 0.23}, 'morales': {'adams': 0.02, 'wiley': 0.43, 'garcia': 0.17, 'yang': 0.94, 'stringer': 0.2, 'morales': 1}}
# ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# adams         253234  Hopeful
# wiley         177722  Hopeful
# garcia        155812  Hopeful
# yang           93291  Rejected
# stringer       40244  Rejected
# morales        22221  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# adams         253234  Hopeful
# garcia        249103  Hopeful
# wiley         240187  Rejected
# yang               0  Rejected
# stringer           0  Rejected
# morales            0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# adams         430956  Elected
# garcia        311568  Rejected
# wiley              0  Rejected
# yang               0  Rejected
# stringer           0  Rejected
# morales            0  Rejected
#
# {'adams': {'adams': 1, 'wiley': 0.05, 'garcia': 0.53, 'yang': 0.98, 'stringer': 0.48, 'morales': 0.92}, 'wiley': {'adams': 0.98, 'wiley': 1, 'garcia': 0.53, 'yang': 0.08, 'stringer': 0.63, 'morales': 0.55}, 'garcia': {'adams': 0.94, 'wiley': 0.02, 'garcia': 1, 'yang': 0.64, 'stringer': 0.16, 'morales': 0.57}, 'yang': {'adams': 0.83, 'wiley': 0.45, 'garcia': 0.85, 'yang': 1, 'stringer': 0.33, 'morales': 0.64}, 'stringer': {'adams': 0.69, 'wiley': 0.63, 'garcia': 0.03, 'yang': 0.25, 'stringer': 1, 'morales': 0.89}, 'morales': {'adams': 0.95, 'wiley': 0.92, 'garcia': 0.56, 'yang': 0.57, 'stringer': 0.98, 'morales': 1}}
# ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# adams         253234  Hopeful
# wiley         177722  Hopeful
# garcia        155812  Hopeful
# yang           93291  Rejected
# stringer       40244  Rejected
# morales        22221  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# adams         315699  Hopeful
# garcia        249103  Hopeful
# wiley         177722  Rejected
# yang               0  Rejected
# stringer           0  Rejected
# morales            0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# adams         493421  Elected
# garcia        249103  Rejected
# wiley              0  Rejected
# yang               0  Rejected
# stringer           0  Rejected
# morales            0  Rejected
#
# {'adams': {'adams': 1, 'wiley': 0.94, 'garcia': 0.69, 'yang': 0.02, 'stringer': 0.23, 'morales': 0.57}, 'wiley': {'adams': 0.51, 'wiley': 1, 'garcia': 0.69, 'yang': 0.05, 'stringer': 0.71, 'morales': 0.5}, 'garcia': {'adams': 0.19, 'wiley': 0.33, 'garcia': 1, 'yang': 0.37, 'stringer': 0.56, 'morales': 0.31}, 'yang': {'adams': 0.1, 'wiley': 0.63, 'garcia': 0.54, 'yang': 1, 'stringer': 0.07, 'morales': 0.06}, 'stringer': {'adams': 0.69, 'wiley': 0.98, 'garcia': 0.12, 'yang': 0.39, 'stringer': 1, 'morales': 0.93}, 'morales': {'adams': 0.0, 'wiley': 0.47, 'garcia': 0.16, 'yang': 0.99, 'stringer': 0.38, 'morales': 1}}
# ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# adams         253234  Hopeful
# wiley         177722  Hopeful
# garcia        155812  Hopeful
# yang           93291  Rejected
# stringer       40244  Rejected
# morales        22221  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# wiley         333478  Hopeful
# adams         253234  Hopeful
# garcia        155812  Rejected
# yang               0  Rejected
# stringer           0  Rejected
# morales            0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# wiley         489290  Elected
# adams         253234  Rejected
# garcia             0  Rejected
# yang               0  Rejected
# stringer           0  Rejected
# morales            0  Rejected
#
# {'adams': {'adams': 1, 'wiley': 0.47, 'garcia': 0.76, 'yang': 0.82, 'stringer': 0.62, 'morales': 0.32}, 'wiley': {'adams': 0.7, 'wiley': 1, 'garcia': 0.51, 'yang': 0.94, 'stringer': 0.76, 'morales': 0.19}, 'garcia': {'adams': 0.19, 'wiley': 0.27, 'garcia': 1, 'yang': 0.32, 'stringer': 0.35, 'morales': 0.7}, 'yang': {'adams': 0.96, 'wiley': 0.76, 'garcia': 0.35, 'yang': 1, 'stringer': 0.19, 'morales': 0.37}, 'stringer': {'adams': 0.82, 'wiley': 0.34, 'garcia': 0.52, 'yang': 0.19, 'stringer': 1, 'morales': 0.8}, 'morales': {'adams': 0.15, 'wiley': 0.51, 'garcia': 0.58, 'yang': 0.75, 'stringer': 0.66, 'morales': 1}}
# ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# adams         253234  Hopeful
# wiley         177722  Hopeful
# garcia        155812  Hopeful
# yang           93291  Rejected
# stringer       40244  Rejected
# morales        22221  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# adams         386769  Elected
# garcia        178033  Rejected
# wiley         177722  Rejected
# yang               0  Rejected
# stringer           0  Rejected
# morales            0  Rejected
#
# {'adams': {'adams': 1, 'wiley': 0.75, 'garcia': 0.11, 'yang': 0.78, 'stringer': 0.82, 'morales': 0.63}, 'wiley': {'adams': 0.97, 'wiley': 1, 'garcia': 0.54, 'yang': 0.41, 'stringer': 0.7, 'morales': 0.45}, 'garcia': {'adams': 0.66, 'wiley': 0.76, 'garcia': 1, 'yang': 0.25, 'stringer': 0.09, 'morales': 0.16}, 'yang': {'adams': 0.79, 'wiley': 0.93, 'garcia': 0.51, 'yang': 1, 'stringer': 0.27, 'morales': 0.53}, 'stringer': {'adams': 0.95, 'wiley': 0.42, 'garcia': 0.28, 'yang': 0.85, 'stringer': 1, 'morales': 0.93}, 'morales': {'adams': 0.69, 'wiley': 0.97, 'garcia': 0.06, 'yang': 0.12, 'stringer': 0.8, 'morales': 1}}
# ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# adams         253234  Hopeful
# wiley         177722  Hopeful
# garcia        155812  Hopeful
# yang           93291  Rejected
# stringer       40244  Rejected
# morales        22221  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# adams         293478  Hopeful
# wiley         293234  Hopeful
# garcia        155812  Rejected
# yang               0  Rejected
# stringer           0  Rejected
# morales            0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# wiley         449046  Elected
# adams         293478  Rejected
# garcia             0  Rejected
# yang               0  Rejected
# stringer           0  Rejected
# morales            0  Rejected
#
# {'adams': {'adams': 1, 'wiley': 0.23, 'garcia': 0.52, 'yang': 0.57, 'stringer': 0.45, 'morales': 0.61}, 'wiley': {'adams': 0.75, 'wiley': 1, 'garcia': 0.99, 'yang': 0.17, 'stringer': 0.1, 'morales': 0.99}, 'garcia': {'adams': 0.87, 'wiley': 0.9, 'garcia': 1, 'yang': 0.25, 'stringer': 0.58, 'morales': 0.31}, 'yang': {'adams': 0.85, 'wiley': 0.38, 'garcia': 0.9, 'yang': 1, 'stringer': 0.46, 'morales': 0.27}, 'stringer': {'adams': 0.45, 'wiley': 0.44, 'garcia': 0.95, 'yang': 0.45, 'stringer': 1, 'morales': 0.07}, 'morales': {'adams': 0.09, 'wiley': 0.59, 'garcia': 0.07, 'yang': 0.23, 'stringer': 0.19, 'morales': 1}}
# ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# adams         253234  Hopeful
# wiley         177722  Hopeful
# garcia        155812  Hopeful
# yang           93291  Rejected
# stringer       40244  Rejected
# morales        22221  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# garcia        289347  Hopeful
# adams         253234  Hopeful
# wiley         199943  Rejected
# yang               0  Rejected
# stringer           0  Rejected
# morales            0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# garcia        467069  Elected
# adams         253234  Rejected
# wiley              0  Rejected
# yang               0  Rejected
# stringer           0  Rejected
# morales            0  Rejected
# Blank votes    22221  Rejected
#
# {'adams': {'adams': 1, 'wiley': 0.97, 'garcia': 0.08, 'yang': 0.25, 'stringer': 0.12, 'morales': 0.07}, 'wiley': {'adams': 0.15, 'wiley': 1, 'garcia': 0.71, 'yang': 0.95, 'stringer': 0.46, 'morales': 0.49}, 'garcia': {'adams': 0.13, 'wiley': 0.26, 'garcia': 1, 'yang': 0.67, 'stringer': 0.64, 'morales': 0.12}, 'yang': {'adams': 0.42, 'wiley': 0.63, 'garcia': 0.2, 'yang': 1, 'stringer': 0.8, 'morales': 0.08}, 'stringer': {'adams': 0.03, 'wiley': 0.27, 'garcia': 0.68, 'yang': 0.87, 'stringer': 1, 'morales': 0.54}, 'morales': {'adams': 0.56, 'wiley': 0.14, 'garcia': 0.72, 'yang': 0.72, 'stringer': 0.32, 'morales': 1}}
# ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# adams         253234  Hopeful
# wiley         177722  Hopeful
# garcia        155812  Hopeful
# yang           93291  Rejected
# stringer       40244  Rejected
# morales        22221  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# wiley         271013  Hopeful
# adams         253234  Hopeful
# garcia        218277  Rejected
# yang               0  Rejected
# stringer           0  Rejected
# morales            0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# wiley         467069  Elected
# adams         275455  Rejected
# garcia             0  Rejected
# yang               0  Rejected
# stringer           0  Rejected
# morales            0  Rejected
#
# {'adams': {'adams': 1, 'wiley': 0.93, 'garcia': 0.06, 'yang': 0.54, 'stringer': 0.26, 'morales': 0.09}, 'wiley': {'adams': 0.23, 'wiley': 1, 'garcia': 0.55, 'yang': 0.51, 'stringer': 0.12, 'morales': 0.86}, 'garcia': {'adams': 0.07, 'wiley': 0.27, 'garcia': 1, 'yang': 0.43, 'stringer': 0.78, 'morales': 0.66}, 'yang': {'adams': 0.09, 'wiley': 0.12, 'garcia': 0.09, 'yang': 1, 'stringer': 0.68, 'morales': 0.89}, 'stringer': {'adams': 0.17, 'wiley': 0.53, 'garcia': 0.42, 'yang': 0.47, 'stringer': 1, 'morales': 0.69}, 'morales': {'adams': 0.74, 'wiley': 0.54, 'garcia': 0.6, 'yang': 0.26, 'stringer': 0.68, 'morales': 1}}
# ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# adams         253234  Hopeful
# wiley         177722  Hopeful
# garcia        155812  Hopeful
# yang           93291  Rejected
# stringer       40244  Rejected
# morales        22221  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# wiley         311257  Hopeful
# adams         275455  Hopeful
# garcia        155812  Rejected
# yang               0  Rejected
# stringer           0  Rejected
# morales            0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# wiley         467069  Elected
# adams         275455  Rejected
# garcia             0  Rejected
# yang               0  Rejected
# stringer           0  Rejected
# morales            0  Rejected
#
# {'adams': {'adams': 1, 'wiley': 0.89, 'garcia': 0.64, 'yang': 0.82, 'stringer': 0.21, 'morales': 0.32}, 'wiley': {'adams': 0.64, 'wiley': 1, 'garcia': 0.66, 'yang': 0.0, 'stringer': 0.54, 'morales': 0.12}, 'garcia': {'adams': 0.66, 'wiley': 0.26, 'garcia': 1, 'yang': 0.13, 'stringer': 0.41, 'morales': 0.06}, 'yang': {'adams': 0.86, 'wiley': 0.3, 'garcia': 0.27, 'yang': 1, 'stringer': 0.18, 'morales': 0.59}, 'stringer': {'adams': 0.92, 'wiley': 0.87, 'garcia': 0.46, 'yang': 0.29, 'stringer': 1, 'morales': 0.16}, 'morales': {'adams': 0.74, 'wiley': 0.26, 'garcia': 0.27, 'yang': 0.7, 'stringer': 0.87, 'morales': 1}}
# ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# adams         253234  Hopeful
# wiley         177722  Hopeful
# garcia        155812  Hopeful
# yang           93291  Rejected
# stringer       40244  Rejected
# morales        22221  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# adams         408990  Elected
# wiley         177722  Rejected
# garcia        155812  Rejected
# yang               0  Rejected
# stringer           0  Rejected
# morales            0  Rejected
#
# {'adams': {'adams': 1, 'wiley': 0.66, 'garcia': 0.42, 'yang': 0.19, 'stringer': 0.81, 'morales': 0.04}, 'wiley': {'adams': 0.99, 'wiley': 1, 'garcia': 0.82, 'yang': 0.52, 'stringer': 0.28, 'morales': 0.12}, 'garcia': {'adams': 0.04, 'wiley': 0.48, 'garcia': 1, 'yang': 0.41, 'stringer': 0.81, 'morales': 0.04}, 'yang': {'adams': 0.01, 'wiley': 0.75, 'garcia': 0.9, 'yang': 1, 'stringer': 0.67, 'morales': 0.4}, 'stringer': {'adams': 0.92, 'wiley': 0.5, 'garcia': 0.94, 'yang': 0.78, 'stringer': 1, 'morales': 0.01}, 'morales': {'adams': 0.79, 'wiley': 0.21, 'garcia': 0.01, 'yang': 0.66, 'stringer': 0.8, 'morales': 1}}
# ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# adams         253234  Hopeful
# wiley         177722  Hopeful
# garcia        155812  Hopeful
# yang           93291  Rejected
# stringer       40244  Rejected
# morales        22221  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# garcia        289347  Hopeful
# adams         275455  Hopeful
# wiley         177722  Rejected
# yang               0  Rejected
# stringer           0  Rejected
# morales            0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# adams         453177  Elected
# garcia        289347  Rejected
# wiley              0  Rejected
# yang               0  Rejected
# stringer           0  Rejected
# morales            0  Rejected
#
# {'adams': {'adams': 1, 'wiley': 0.09, 'garcia': 0.2, 'yang': 0.54, 'stringer': 0.25, 'morales': 0.36}, 'wiley': {'adams': 0.35, 'wiley': 1, 'garcia': 0.72, 'yang': 0.44, 'stringer': 0.08, 'morales': 0.09}, 'garcia': {'adams': 0.17, 'wiley': 0.35, 'garcia': 1, 'yang': 0.2, 'stringer': 0.9, 'morales': 0.84}, 'yang': {'adams': 0.08, 'wiley': 0.81, 'garcia': 0.69, 'yang': 1, 'stringer': 0.24, 'morales': 0.04}, 'stringer': {'adams': 0.74, 'wiley': 0.85, 'garcia': 0.86, 'yang': 0.38, 'stringer': 1, 'morales': 0.64}, 'morales': {'adams': 0.48, 'wiley': 0.77, 'garcia': 0.12, 'yang': 0.19, 'stringer': 0.88, 'morales': 1}}
# ROUND 1
# Candidate      Votes  Status
# -----------  -------  --------
# adams         253234  Hopeful
# wiley         177722  Hopeful
# garcia        155812  Hopeful
# yang           93291  Rejected
# stringer       40244  Rejected
# morales        22221  Rejected
#
# ROUND 2
# Candidate      Votes  Status
# -----------  -------  --------
# wiley         293234  Hopeful
# adams         253234  Hopeful
# garcia        196056  Rejected
# yang               0  Rejected
# stringer           0  Rejected
# morales            0  Rejected
#
# FINAL RESULT
# Candidate      Votes  Status
# -----------  -------  --------
# wiley         489290  Elected
# adams         253234  Rejected
# garcia             0  Rejected
# yang               0  Rejected
# stringer           0  Rejected
# morales            0  Rejected

# %%
favor_web["yang"]["garcia"] = round(random.uniform(.5,.99),2)
print(favor_web["yang"]["garcia"])
# Out:
# 0.97

# %%
print(winners)
# Out:
# {'adams': 20, 'wiley': 6, 'garcia': 4, 'yang': 0, 'stringer': 0, 'morales': 0}

# %%
{'adams': 9, 'wiley': 0, 'garcia': 1, 'yang': 0, 'stringer': 0, 'morales': 0}
{'adams': 28, 'wiley': 14, 'garcia': 8, 'yang': 0, 'stringer': 0, 'morales': 0}

# %%
{'adams': 
    {'adams': 1, 'wiley': 0.74, 'garcia': 0.36, 'yang': 0.24, 'stringer': 0.12, 'morales': 0.18}, 
'wiley': 
    {'adams': 0.58, 'wiley': 1, 'garcia': 0.67, 'yang': 0.97, 'stringer': 0.11, 'morales': 0.07}, 
'garcia': 
    {'adams': 0.82, 'wiley': 0.64, 'garcia': 1, 'yang': 0.87, 'stringer': 0.62, 'morales': 0.16}, 
'yang': 
    {'adams': 0.15, 'wiley': 0.56, 'garcia': 0.9, 'yang': 1, 'stringer': 0.16, 'morales': 0.44}, 
'stringer': 
    {'adams': 0.4, 'wiley': 0.89, 'garcia': 0.27, 'yang': 0.77, 'stringer': 1, 'morales': 0.83}, 
'morales': 
    {'adams': 0.58, 'wiley': 0.4, 'garcia': 0.71, 'yang': 0.07, 'stringer': 0.96, 'morales': 1}}
